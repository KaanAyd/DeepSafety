# %% [markdown]
# ## Final Project - Submission
#
# This documentation provides a comprehensive overview of the development and implementation of a neural network model for traffic sign classification.

# %%
# imports
import sys
 
sys.path.append("..")
 
from pathlib import Path
import mlflow
import torch.nn as nn
import matplotlib.pyplot as plt
 
from eval import evaluate, load_and_transform_data, get_sign_names, get_monte_carlo_predictions, SafetyBatchDataset
 
ROOT_DIR = Path().cwd().parent
BATCH_DIR = ROOT_DIR / "safetyBatches" / "Batch_5"
 
# Set the tracking server to be localhost with sqlite as tracking store
mlflow.set_tracking_uri(uri=f"sqlite:///{ROOT_DIR / 'mlruns.db'}")
 
# TODO: make sure you use the MLFlow run ID of your trained model
RUN_ID = "3737831d8c5e4f2c976b6bbde4ea97c0"     # with transformation
# RUN_ID = "633d2ccbf97943a3b9ed0a820c5baca1"   # without transformation
 
model_uri = f"runs:/{RUN_ID}/model"
loaded_model = mlflow.pytorch.load_model(model_uri)

# newcommand Monte-Carlo-Dropout
# num_forward_passes = 50
# num_classes = 43

# mean_value, variance_value = get_monte_carlo_predictions(
#     batch_loader, num_forward_passes, loaded_model, num_classes, len(batch_loader.dataset)
# )

criterion = nn.CrossEntropyLoss()
 
batch_loader = load_and_transform_data(data_directory_path=str(BATCH_DIR))
 
# newcommand
mlflow.end_run()
 
# newcommand
with mlflow.start_run(run_id=RUN_ID):
 
# TODO: track evaluation results
    predictions = evaluate(loaded_model, criterion, batch_loader, BATCH_DIR.name)
 
    # Output incorrect classifications
    ground_truth = []
    for _, target in batch_loader:
        ground_truth.extend(target.tolist())
    sign_names = get_sign_names()
    wrong_predictions_idx = [
        idx for idx, (y_pred, y) in enumerate(zip(predictions, ground_truth)) if y_pred != y
    ]
    for idx in wrong_predictions_idx:
        # image, target = batch_loader.dataset[idx]
        # plt.figure()
        # plt.imshow(image.permute(1, 2, 0), interpolation='bicubic')
        # plt.show()
        print(
            f"Traffic sign {sign_names[ground_truth[idx]]} incorrectly classified as {sign_names[predictions[idx]]}"
        )
# Out:
# 2024/06/14 19:21:43 WARNING mlflow.pytorch: Stored model version '2.1.2+cpu' does not match installed PyTorch version '2.2.2+cpu'
# Safety batch: Average loss: 0.0202, Accuracy: 76.1 %, Precision: 27.3 %
# Traffic sign Speed limit (20km/h) incorrectly classified as Speed limit (30km/h)
# Traffic sign Speed limit (20km/h) incorrectly classified as Speed limit (50km/h)
# Traffic sign Speed limit (20km/h) incorrectly classified as Speed limit (50km/h)
# Traffic sign Speed limit (20km/h) incorrectly classified as Speed limit (30km/h)
# Traffic sign Speed limit (20km/h) incorrectly classified as Speed limit (30km/h)
# Traffic sign Speed limit (30km/h) incorrectly classified as Road narrows on the right
# Traffic sign Speed limit (30km/h) incorrectly classified as Dangerous curve to the right
# Traffic sign Speed limit (30km/h) incorrectly classified as Road work
# Traffic sign Speed limit (30km/h) incorrectly classified as Yield
# Traffic sign Speed limit (30km/h) incorrectly classified as Dangerous curve to the left
# Traffic sign Speed limit (30km/h) incorrectly classified as Dangerous curve to the left
# Traffic sign Speed limit (30km/h) incorrectly classified as Traffic signals
# Traffic sign Speed limit (30km/h) incorrectly classified as Dangerous curve to the left
# Traffic sign Speed limit (30km/h) incorrectly classified as Speed limit (100km/h)
# Traffic sign Right-of-way at the next intersection incorrectly classified as Road work
# Traffic sign Right-of-way at the next intersection incorrectly classified as Pedestrians
# Traffic sign Right-of-way at the next intersection incorrectly classified as Pedestrians
# Traffic sign Priority road incorrectly classified as Road work
# Traffic sign Stop incorrectly classified as Speed limit (80km/h)
# Traffic sign No vehicles incorrectly classified as Yield
# Traffic sign No vehicles incorrectly classified as Yield
# Traffic sign No entry incorrectly classified as Stop
# Traffic sign Dangerous curve to the left incorrectly classified as Slippery road
# Traffic sign Speed limit (50km/h) incorrectly classified as Speed limit (80km/h)
# Traffic sign Speed limit (50km/h) incorrectly classified as Keep right
# Traffic sign Speed limit (50km/h) incorrectly classified as Speed limit (80km/h)
# Traffic sign Speed limit (50km/h) incorrectly classified as Speed limit (80km/h)
# Traffic sign Speed limit (50km/h) incorrectly classified as Speed limit (80km/h)
# Traffic sign Speed limit (50km/h) incorrectly classified as Priority road
# Traffic sign Speed limit (50km/h) incorrectly classified as Priority road
# Traffic sign Speed limit (50km/h) incorrectly classified as Speed limit (80km/h)
# Traffic sign Speed limit (50km/h) incorrectly classified as Wild animals crossing
# Traffic sign Speed limit (50km/h) incorrectly classified as Speed limit (100km/h)
# Traffic sign Speed limit (50km/h) incorrectly classified as Speed limit (100km/h)
# Traffic sign Speed limit (50km/h) incorrectly classified as Speed limit (80km/h)
# Traffic sign Dangerous curve to the right incorrectly classified as Slippery road
# Traffic sign Dangerous curve to the right incorrectly classified as Children crossing
# Traffic sign Dangerous curve to the right incorrectly classified as Slippery road
# Traffic sign Double curve incorrectly classified as Wild animals crossing
# Traffic sign Double curve incorrectly classified as Road work
# Traffic sign Double curve incorrectly classified as Road work
# Traffic sign Double curve incorrectly classified as Wild animals crossing
# Traffic sign Double curve incorrectly classified as Wild animals crossing
# Traffic sign Bumpy road incorrectly classified as Beware of ice/snow
# Traffic sign Slippery road incorrectly classified as Wild animals crossing
# Traffic sign Slippery road incorrectly classified as Beware of ice/snow
# Traffic sign Slippery road incorrectly classified as Beware of ice/snow
# Traffic sign Slippery road incorrectly classified as Beware of ice/snow
# Traffic sign Slippery road incorrectly classified as Beware of ice/snow
# Traffic sign Slippery road incorrectly classified as Speed limit (120km/h)
# Traffic sign Slippery road incorrectly classified as Speed limit (120km/h)
# Traffic sign Road narrows on the right incorrectly classified as Road work
# Traffic sign Road narrows on the right incorrectly classified as Road work
# Traffic sign Pedestrians incorrectly classified as General caution
# Traffic sign Pedestrians incorrectly classified as Road work
# Traffic sign Pedestrians incorrectly classified as Road narrows on the right
# Traffic sign Pedestrians incorrectly classified as Road work
# Traffic sign Pedestrians incorrectly classified as Road narrows on the right
# Traffic sign Pedestrians incorrectly classified as Speed limit (50km/h)
# Traffic sign Pedestrians incorrectly classified as Yield
# Traffic sign Pedestrians incorrectly classified as Road narrows on the right
# Traffic sign Pedestrians incorrectly classified as Road narrows on the right
# Traffic sign Pedestrians incorrectly classified as Road work
# Traffic sign Speed limit (60km/h) incorrectly classified as Speed limit (30km/h)
# Traffic sign Speed limit (60km/h) incorrectly classified as Speed limit (80km/h)
# Traffic sign Speed limit (60km/h) incorrectly classified as Speed limit (80km/h)
# Traffic sign Speed limit (60km/h) incorrectly classified as Speed limit (80km/h)
# Traffic sign Speed limit (60km/h) incorrectly classified as Speed limit (80km/h)
# Traffic sign Beware of ice/snow incorrectly classified as Children crossing
# Traffic sign Beware of ice/snow incorrectly classified as Speed limit (30km/h)
# Traffic sign Beware of ice/snow incorrectly classified as Right-of-way at the next intersection
# Traffic sign Beware of ice/snow incorrectly classified as Right-of-way at the next intersection
# Traffic sign Beware of ice/snow incorrectly classified as Right-of-way at the next intersection
# Traffic sign Beware of ice/snow incorrectly classified as Road work
# Traffic sign Wild animals crossing incorrectly classified as Double curve
# Traffic sign Wild animals crossing incorrectly classified as No entry
# Traffic sign Wild animals crossing incorrectly classified as Dangerous curve to the left
# Traffic sign Wild animals crossing incorrectly classified as Slippery road
# Traffic sign Wild animals crossing incorrectly classified as No passing
# Traffic sign Wild animals crossing incorrectly classified as Speed limit (30km/h)
# Traffic sign Wild animals crossing incorrectly classified as Speed limit (30km/h)
# Traffic sign Wild animals crossing incorrectly classified as Slippery road
# Traffic sign End of all speed and passing limits incorrectly classified as Road work
# Traffic sign End of all speed and passing limits incorrectly classified as End of speed limit (80km/h)
# Traffic sign End of all speed and passing limits incorrectly classified as End of speed limit (80km/h)
# Traffic sign End of all speed and passing limits incorrectly classified as Road work
# Traffic sign Turn right ahead incorrectly classified as Roundabout mandatory
# Traffic sign Turn right ahead incorrectly classified as Roundabout mandatory
# Traffic sign Turn right ahead incorrectly classified as Roundabout mandatory
# Traffic sign Turn left ahead incorrectly classified as Ahead only
# Traffic sign Turn left ahead incorrectly classified as Keep right
# Traffic sign Turn left ahead incorrectly classified as Keep right
# Traffic sign Turn left ahead incorrectly classified as Keep right
# Traffic sign Turn left ahead incorrectly classified as Ahead only
# Traffic sign Go straight or right incorrectly classified as Keep right
# Traffic sign Go straight or right incorrectly classified as Keep right
# Traffic sign Go straight or right incorrectly classified as Keep right
# Traffic sign Go straight or left incorrectly classified as Roundabout mandatory
# Traffic sign Speed limit (70km/h) incorrectly classified as Priority road
# Traffic sign Speed limit (70km/h) incorrectly classified as Dangerous curve to the left
# Traffic sign Speed limit (70km/h) incorrectly classified as Speed limit (60km/h)
# Traffic sign Speed limit (70km/h) incorrectly classified as Speed limit (50km/h)
# Traffic sign Speed limit (70km/h) incorrectly classified as Right-of-way at the next intersection
# Traffic sign End of no passing incorrectly classified as Vehicles over 3.5 metric tons prohibited
# Traffic sign End of no passing incorrectly classified as End of all speed and passing limits
# Traffic sign End of no passing incorrectly classified as End of all speed and passing limits
# Traffic sign End of no passing by vehicles over 3.5 metric tons incorrectly classified as End of speed limit (80km/h)
# Traffic sign End of no passing by vehicles over 3.5 metric tons incorrectly classified as End of speed limit (80km/h)
# Traffic sign End of no passing by vehicles over 3.5 metric tons incorrectly classified as End of speed limit (80km/h)
# Traffic sign End of no passing by vehicles over 3.5 metric tons incorrectly classified as End of speed limit (80km/h)
# Traffic sign End of no passing by vehicles over 3.5 metric tons incorrectly classified as End of speed limit (80km/h)
# Traffic sign Speed limit (80km/h) incorrectly classified as Speed limit (50km/h)
# Traffic sign Speed limit (80km/h) incorrectly classified as Speed limit (70km/h)
# Traffic sign Speed limit (80km/h) incorrectly classified as Speed limit (50km/h)
# Traffic sign Speed limit (100km/h) incorrectly classified as Speed limit (80km/h)
# Traffic sign Speed limit (100km/h) incorrectly classified as Speed limit (80km/h)
# Traffic sign Speed limit (100km/h) incorrectly classified as Speed limit (80km/h)
# Traffic sign Speed limit (100km/h) incorrectly classified as Speed limit (120km/h)
# Traffic sign Speed limit (100km/h) incorrectly classified as Speed limit (80km/h)
# Traffic sign Speed limit (100km/h) incorrectly classified as Speed limit (80km/h)
# Traffic sign Speed limit (100km/h) incorrectly classified as Speed limit (80km/h)
# Traffic sign Speed limit (100km/h) incorrectly classified as Speed limit (20km/h)
# Traffic sign Speed limit (120km/h) incorrectly classified as Speed limit (20km/h)
# Traffic sign Speed limit (120km/h) incorrectly classified as Speed limit (20km/h)
# Traffic sign Speed limit (120km/h) incorrectly classified as Speed limit (50km/h)
# Traffic sign Speed limit (120km/h) incorrectly classified as Speed limit (50km/h)
# Traffic sign Speed limit (120km/h) incorrectly classified as Speed limit (50km/h)
# Traffic sign Speed limit (120km/h) incorrectly classified as Speed limit (30km/h)
# Traffic sign Speed limit (120km/h) incorrectly classified as Speed limit (20km/h)
# Traffic sign Speed limit (120km/h) incorrectly classified as Speed limit (20km/h)
# Traffic sign Speed limit (120km/h) incorrectly classified as Speed limit (20km/h)
# Traffic sign Speed limit (120km/h) incorrectly classified as Speed limit (70km/h)

# %% [markdown]
# # Determination of robustness:
#
# First try without data augmentation: 'Safety batch: Average loss: 0.0202, Accuracy: 76.1 %, Precision: 27.3 %'
#
# Correctly classified images without transformation: 446 images
#
# Accuracy after adding the transformation: 14.1%
#
# Now we calculate <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mrow>
#     <mn>0.141</mn>
#     <mo>&#x00D7;</mo>
#     <mn>446</mn>
#     <mo>=</mo>
#     <mn>62.886</mn>
#   </mrow>
# </math>
# to get the number of correctly classified images after the transformation. Here: 63 images
#
# Our robustness value is calculated as <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mrow>
#     <mn>63</mn>
#     <mo>&#x00F7;</mo>
#     <mn>552</mn>
#   </mrow>
# </math>
# and is 0.114 or 11.4%

# %% [markdown]
# ---------------------------------------------

# %% [markdown]
# # Contact Information
#
# - **Name:** Kaan Aydin
#
# - **Course:** TFE21-2
#
# - **Company:** ZF Friedrichshafen AG
#
# - **Director of Studies:** Prof. Dr.-Ing. Thomas Kibler
#
# - **Mail:** [kaan.aydin@zf.com](mailto:DeineEmail@example.com)
#
# - **University Mail:** [aydin.kaan-it21@it.dhbw-ravensburg.de](mailto:DeineEmail@example.com)
#
# - <a href="https://www.linkedin.com/in/kaan-ayd/"><img src="https://upload.wikimedia.org/wikipedia/commons/e/e9/Linkedin_icon.svg" alt="LinkedIn" style="width:20px;height:20px;"></a> Kaan Aydin - LinkedIn
#
# - <a href="https://github.com/KaanAyd"><img src="https://upload.wikimedia.org/wikipedia/commons/9/91/Octicons-mark-github.svg" alt="GitHub" style="width:20px;height:20px;"></a> Kaan Aydin - GitHub
